# %%
# imports and api_keys
from langchain import OpenAI, LLMMathChain, SerpAPIWrapper, WolframAlphaAPIWrapper
from langchain.agents import initialize_agent, Tool
from langchain.chat_models import ChatOpenAI

# read in the api key from file apikeys.txt. with file path C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\openai_key.txt
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\openai_key.txt", "r") as f:
    openai_api_key = f.read()

# read in serp api key from C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\serpapi_key.txt
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\serpapi_key.txt", "r") as f:
    serp_api_key = f.read()

# read in wolfram alpha api key from C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\wolfram_appid.txt
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\wolfram_appid.txt", "r") as f:
    wolfram_appid = f.read()

# %%
import json
import pandas as pd

# read in json file C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\math_tests\challenge_test.json
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\math_tests\\challenge_test.json", "r") as f:
    challenge_test = json.load(f)

# convert the json file to a pandas dataframe
challenge_test_df = pd.DataFrame(challenge_test)

# cut down dataset to only rows 100-200
challenge_test_df = challenge_test_df.iloc[100:200]

# %%
# read in C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\math_tests\my_test.txt and save each line as and element in a list
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\math_tests\\my_test.txt", "r") as f:
    my_test = f.readlines()

# %%
# create a new list that is just the questions and answers
# the questions are comprise of combining the problem column and the options column
# the answers are just the correct column
challenge_test_questions_answers = []
for i in range(len(challenge_test_df)):
    question = challenge_test_df.iloc[i]['Problem'] + " " + challenge_test_df.iloc[i]['options']
    answer = challenge_test_df.iloc[i]['correct']
    challenge_test_questions_answers.append((question, answer))

# %%
llm = ChatOpenAI(temperature=0, openai_api_key=openai_api_key)
llm1 = OpenAI(temperature=0, openai_api_key=openai_api_key)
search = SerpAPIWrapper(serpapi_api_key=serp_api_key)
llm_math_chain = LLMMathChain(llm=llm1, verbose=True)
wolfram = WolframAlphaAPIWrapper(wolfram_alpha_appid=wolfram_appid)
tools = [
    Tool(
        name = "Search",
        func=search.run,
        description="useful for when you need to answer questions about current events. You should ask targeted questions"
    ),
    Tool(
        name="Calculator",
        func=llm_math_chain.run,
        description="useful for when you need to answer simple questions about math"
    )      
]

# %%
mrkl = initialize_agent(tools, llm, agent="zero-shot-react-description", verbose=True)

# %%
# langchain
from langchain.llms import OpenAI
from langchain.agents import load_tools, initialize_agent


serpapi_api_key=serp_api_key

# # # # # # wolfram alpha app_id
app_id = wolfram_appid

# old way of initializing agent
# initialize agent
tool_names = ['serpapi', 'wolfram-alpha', 'pal-math'] # 'open-meteo-api', 'tmdb-api', 'pal-colored-objects'
llm = OpenAI(model_name="text-davinci-003", openai_api_key=openai_api_key)
tools = load_tools(tool_names, llm=llm)
agent = initialize_agent(tools, llm, agent="zero-shot-react-description", verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# c:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\MyAgent_test_taking_script.ipynb Cell 7 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a> tool_names = ['serpapi', 'wolfram-alpha', 'pal-math'] # 'open-meteo-api', 'tmdb-api', 'pal-colored-objects'
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a> llm = OpenAI(model_name="text-davinci-003", openai_api_key=openai_api_key)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a> tools = load_tools(tool_names, llm=llm)
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> agent = initialize_agent(tools, llm, agent="zero-shot-react-description", verbose=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\load_tools.py:224, in load_tools(tool_names, llm, callback_manager, **kwargs)
#     222 _get_tool_func, extra_keys = _EXTRA_OPTIONAL_TOOLS[name]
#     223 sub_kwargs = {k: kwargs[k] for k in extra_keys if k in kwargs}
# --> 224 tool = _get_tool_func(**sub_kwargs)
#     225 if callback_manager is not None:
#     226     tool.callback_manager = callback_manager
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\load_tools.py:143, in _get_serpapi(**kwargs)
#     139 def _get_serpapi(**kwargs: Any) -> BaseTool:
#     140     return Tool(
#     141         name="Search",
#     142         description="A search engine. Useful for when you need to answer questions about current events. Input should be a search query.",
# --> 143         func=SerpAPIWrapper(**kwargs).run,
#     144         coroutine=SerpAPIWrapper(**kwargs).arun,
#     145     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pydantic\main.py:331, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for SerpAPIWrapper
# __root__
#   Did not find serpapi_api_key, please add an environment variable `SERPAPI_API_KEY` which contains it, or pass  `serpapi_api_key` as a named parameter. (type=value_error)

# %%
# test to see if model is working
# mrkl.run("""What is the height of Mount Everest in meters divided by the length of the Golden Gate Bridge in meters?""")

# %%
# testing my model on my questions
# redirect stdout to file for logging
import sys
import re
sys.stdout = open(r'C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\MRKL_chat_test.txt', 'w', encoding="utf-8")
i = 1
# create a variable to hold the number of questions
num_questions = len(my_test)
# create a list called answers to hold the answers to the questions
answers = []
# create a variable to hold the number of correct answers
num_correct = 0
# loop through the questions and ask mrkl each question
for question in my_test:
    print(f'=============================Q{i}==============================================================\n')
    # with nice formating write the question that the agent will be asked
    print(f"Question: {question.encode('utf-8').decode('cp1252')} \n")
    # ask the agent the question
    print('---------------------------------------------------------------\n')
    # try to have the agent answer the question. if the agent fails to answer the question then return agent failed to answer and move on to the next question
    try:
        result = mrkl.run(question)
    except Exception as e:
        print(f"\n !!!Agent's Answer: Agent Failed to Answer!!! \n")
        print(f'==============================================================================================\n')

        i += 1
        continue
    
    print('---------------------------------------------------------------\n')
    # with nice formating write the result that the agent gave
    print(f"Agent's Answer: {result} \n")
    # add the answer to the list of answers
    answers.append(result)
    print('---------------------------------------------------------------\n')
    print(f"Agent's Answer: Correct \n")
    num_correct += 1
    print(f'==============================================================================================\n')
    i += 1

# print the number of questions and the number of correct answers
print(f"Number of Questions: {num_questions} \n")
print(f"Number of Correct Answers: {num_correct} \n")
print(f"Accuracy: {num_correct/num_questions} \n")

# %%
# read in the test from C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\deepmind_math_q.txt
with open(r"C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\math_tests\deepmind_100math_test.txt", "r") as f:
    test = f.read()

# the test data is formated as follows: 
# Which is the nearest to 6?  (a) -462/107  (b) 0.3  (c) 6/19
# c
# as you can see the first line holds the question and the second line holds the answer.
# please create a data structure that holds the questions and answers in a list of tuples
# for example: [("Which is the nearest to 6?  (a) -462/107  (b) 0.3  (c) 6/19", "c"), ...]

# split the test data into a list of questions and answers
test = test.split("\n")

# create a list of tuples that hold the questions and answers
test = [(test[i], test[i+1]) for i in range(0, len(test), 2)]

# this is for testing purposes only. please comment out this line when you are done testing
# # cut down the test data to 2 questions
# test = test[:2]

# %%
# choose what dataset you want to test on
# challenge_test_questions_answers
# test

# %%
# testing my model with a set of math questions from deepmind (https://github.com/deepmind/mathematics_dataset)
# redirect stdout to file for logging
import sys
import re
sys.stdout = open(r'C:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\MRKL_chat_test.txt', 'w', encoding="utf-8")
i = 1
# create a variable to hold the number of questions
num_questions = len(challenge_test_questions_answers)
# create a variable to hold the number of correct answers
num_correct = 0
# loop through the questions and ask mrkl each question
for question, answer in challenge_test_questions_answers:
    print(f'=============================Q{i}==============================================================\n')
    # with nice formating write the question that the agent will be asked
    print(f"Question: {question.encode('utf-8').decode('cp1252')} \n")
    # ask the agent the question
    print('---------------------------------------------------------------\n')
    # try to have the agent answer the question. if the agent fails to answer the question then return agent failed to answer and move on to the next question
    try:
        result = mrkl.run(question)
    except Exception as e:
        print(f"\n !!!Agent's Answer: Agent Failed to Answer!!! \n")
        print(f'==============================================================================================\n')
        i += 1
        continue
    
    print('---------------------------------------------------------------\n')
    # with nice formating write the result that the agent gave
    print(f"Agent's Answer: {result} \n")
    print('---------------------------------------------------------------\n')
    # with nice formating write the answer that the agent will be asked
    print(f"Actual Answer: {answer} \n")
    # evaluate if the agent got the answer correct. use regex to see if the answer is in the result
    if re.search(answer, result):
        # if the answer is in the result then the agent got the answer correct
        num_correct += 1
        print(f"Agent's Answer: Correct \n")
    print(f'==============================================================================================\n')
    i += 1

# print the number of questions and the number of correct answers
print(f"Number of Questions: {num_questions} \n")
print(f"Number of Correct Answers: {num_correct} \n")
print(f"Accuracy: {num_correct/num_questions} \n")

# print a list of the answers
print(answers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\cayde\Desktop\Grad_School_stuff\data-534_expo_proj\Synergistic_Computing_hf\benchmarking\MyAgent_test_taking_script.ipynb Cell 9 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a> # try to have the agent answer the question. if the agent fails to answer the question then return agent failed to answer and move on to the next question
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a>     result = mrkl.run(question)
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> except Exception as e:
#      <a href='vscode-notebook-cell:/c%3A/Users/cayde/Desktop/Grad_School_stuff/data-534_expo_proj/Synergistic_Computing_hf/benchmarking/MyAgent_test_taking_script.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>     print(f"\n !!!Agent's Answer: Agent Failed to Answer!!! \n")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\base.py:213, in Chain.run(self, *args, **kwargs)
#     211     if len(args) != 1:
#     212         raise ValueError("`run` supports only one positional argument.")
# --> 213     return self(args[0])[self.output_keys[0]]
#     215 if kwargs and not args:
#     216     return self(kwargs)[self.output_keys[0]]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\agent.py:503, in AgentExecutor._call(self, inputs)
#     501 # We now enter the agent loop (until it returns something).
#     502 while self._should_continue(iterations):
# --> 503     next_step_output = self._take_next_step(
#     504         name_to_tool_map, color_mapping, inputs, intermediate_steps
#     505     )
#     506     if isinstance(next_step_output, AgentFinish):
#     507         return self._return(next_step_output, intermediate_steps)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\agent.py:406, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps)
#     401 """Take a single step in the thought-action-observation loop.
#     402
#     403 Override this to take control of how the agent makes and acts on choices.
#     404 """
#     405 # Call the LLM to see what to do.
# --> 406 output = self.agent.plan(intermediate_steps, **inputs)
#     407 # If the tool chosen is the finishing tool, then we end and return.
#     408 if isinstance(output, AgentFinish):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\agent.py:102, in Agent.plan(self, intermediate_steps, **kwargs)
#      91 """Given input, decided what to do.
#      92
#      93 Args:
#    (...)
#      99     Action specifying what tool to use.
#     100 """
#     101 full_inputs = self.get_full_inputs(intermediate_steps, **kwargs)
# --> 102 action = self._get_next_action(full_inputs)
#     103 if action.tool == self.finish_tool_name:
#     104     return AgentFinish({"output": action.tool_input}, action.log)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\agents\agent.py:63, in Agent._get_next_action(self, full_inputs)
#      62 def _get_next_action(self, full_inputs: Dict[str, str]) -> AgentAction:
# ---> 63     full_output = self.llm_chain.predict(**full_inputs)
#      64     parsed_output = self._extract_tool_and_input(full_output)
#      65     while parsed_output is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\llm.py:151, in LLMChain.predict(self, **kwargs)
#     137 def predict(self, **kwargs: Any) -> str:
#     138     """Format prompt with kwargs and pass to LLM.
#     139
#     140     Args:
#    (...)
#     149             completion = llm.predict(adjective="funny")
#     150     """
# --> 151     return self(kwargs)[self.output_key]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\llm.py:57, in LLMChain._call(self, inputs)
#      56 def _call(self, inputs: Dict[str, Any]) -> Dict[str, str]:
# ---> 57     return self.apply([inputs])[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\llm.py:118, in LLMChain.apply(self, input_list)
#     116 def apply(self, input_list: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#     117     """Utilize the LLM generate method for speed gains."""
# --> 118     response = self.generate(input_list)
#     119     return self.create_outputs(response)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chains\llm.py:62, in LLMChain.generate(self, input_list)
#      60 """Generate LLM result from inputs."""
#      61 prompts, stop = self.prep_prompts(input_list)
# ---> 62 return self.llm.generate_prompt(prompts, stop)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\base.py:63, in BaseChatModel.generate_prompt(self, prompts, stop)
#      59 def generate_prompt(
#      60     self, prompts: List[PromptValue], stop: Optional[List[str]] = None
#      61 ) -> LLMResult:
#      62     prompt_messages = [p.to_messages() for p in prompts]
# ---> 63     return self.generate(prompt_messages, stop=stop)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\base.py:49, in BaseChatModel.generate(self, messages, stop)
#      45 def generate(
#      46     self, messages: List[List[BaseMessage]], stop: Optional[List[str]] = None
#      47 ) -> LLMResult:
#      48     """Top Level call"""
# ---> 49     results = [self._generate(m, stop=stop) for m in messages]
#      50     return LLMResult(generations=[res.generations for res in results])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\base.py:49, in <listcomp>(.0)
#      45 def generate(
#      46     self, messages: List[List[BaseMessage]], stop: Optional[List[str]] = None
#      47 ) -> LLMResult:
#      48     """Top Level call"""
# ---> 49     results = [self._generate(m, stop=stop) for m in messages]
#      50     return LLMResult(generations=[res.generations for res in results])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\openai.py:246, in ChatOpenAI._generate(self, messages, stop)
#     242     message = _convert_dict_to_message(
#     243         {"content": inner_completion, "role": role}
#     244     )
#     245     return ChatResult(generations=[ChatGeneration(message=message)])
# --> 246 response = self.completion_with_retry(messages=message_dicts, **params)
#     247 return _create_chat_result(response)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\openai.py:222, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     218 @retry_decorator
#     219 def _completion_with_retry(**kwargs: Any) -> Any:
#     220     return self.client.create(**kwargs)
# --> 222 return _completion_with_retry(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:437, in Future.result(self, timeout)
#     435     raise CancelledError()
#     436 elif self._state == FINISHED:
# --> 437     return self.__get_result()
#     439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:389, in Future.__get_result(self)
#     387 if self._exception:
#     388     try:
# --> 389         raise self._exception
#     390     finally:
#     391         # Break a reference cycle with the exception in self._exception
#     392         self = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\langchain\chat_models\openai.py:220, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     218 @retry_decorator
#     219 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 220     return self.client.create(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524     )
#     525 except requests.exceptions.Timeout as e:
#     526     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:1344, in HTTPConnection.getresponse(self)
#    1342 try:
#    1343     try:
# -> 1344         response.begin()
#    1345     except ConnectionError:
#    1346         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# set up normal openai davinci model to compare to
import openai
openai.api_key = openai_api_key

def query_davinci_old_version(prompt, model_version="text-davinci-003"):
    response = openai.Completion.create(
        engine=model_version,
        prompt=prompt,
        max_tokens=40,
        n=1,
        stop=None,
        temperature=0.15
    )

    return response.choices[0].text.strip()

# Example usage:
prompt = "What is the height of Mount Everest in meters divided by the length of the Golden Gate Bridge in meters?"
response_text = query_davinci_old_version(prompt)
print(response_text)
# Out:
# The answer is 0.0014.

# %%
# running deepmind_100math_test through the agent
import re
# testing regular open ai model 
# create a new empty txt file to hold the results 
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "w", encoding='utf-8') as f:
    f.write("")

j = 1
num_correct = 0
num_questions = len(my_test)

# loop through the questions and ask mrkl each question
for question in my_test:
    try:
        result = query_davinci_old_version(question)
    except Exception as e:
        result = "Agent Failed to Answer"
        with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
            f.write(f'=============================Q{j}==============================================================\n')
            # with nice formating write the question that the agent will be asked
            f.write(f"Question: {question} \n")
            f.write('---------------------------------------------------------------\n')
            # with nice formating write the result that the agent gave
            f.write(f"Agent's Answer:\n {result} \n")
            f.write('---------------------------------------------------------------\n')
            f.write(f'==============================================================================================\n')
        i += 1
        continue
    # write the question and answer to the results file
    with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
        f.write(f'=============================Q{j}==============================================================\n')
        # with nice formating write the question that the agent will be asked
        f.write(f"Question: {question} \n")
        f.write('---------------------------------------------------------------\n')
        # with nice formating write the result that the agent gave
        f.write(f"Agent's Answer:\n {result} \n")
        f.write(f'==============================================================================================\n')
        
    j += 1

with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
    f.write(f"Number of Questions: {num_questions} \n")
    f.write(f"Number of Correct Answers: {num_correct} \n")
    f.write(f"Accuracy: {num_correct/num_questions} \n")

# print the number of questions and the number of correct answers
print(f"Number of Questions: {num_questions} \n")
print(f"Number of Correct Answers: {num_correct} \n")
print(f"Accuracy: {num_correct/num_questions} \n")
# Out:
# Number of Questions: 50
#
# Number of Correct Answers: 0
#
# Accuracy: 0.0

# %%
import requests

def ask_wolfram_alpha(query, app_id):
    base_url = "http://api.wolframalpha.com/v1/result"
    params = {
        "i": query,
        "appid": app_id,
        "format": "plaintext"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        return response.text
    else:
        raise Exception(f"Error in API call: {response.status_code}: {response.text}")

# Replace YOUR_APP_ID with your actual Wolfram Alpha API key
app_id = "LXATGL-RJ6P2UWYT4"
query = "What is the height of Mount Everest in meters divided by the length of the Golden Gate Bridge in meters?"

try:
    result = ask_wolfram_alpha(query, app_id)
    print(result)
except Exception as e:
    print(e)
# Out:
# about 3.233

# %%
# asking wolfram alpha the questions
import re
# testing regular open ai model 
# create a new empty txt file to hold the results 
with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "w", encoding='utf-8') as f:
    f.write("")

j = 1
num_correct = 0
num_questions = len(my_test)

# loop through the questions and ask mrkl each question
for question in my_test:
    try:
        result = ask_wolfram_alpha(question, app_id)
    except Exception as e:
        result = "Agent Failed to Answer"
        with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
            f.write(f'=============================Q{j}==============================================================\n')
            # with nice formating write the question that the agent will be asked
            f.write(f"Question: {question} \n")
            f.write('---------------------------------------------------------------\n')
            # with nice formating write the result that the agent gave
            f.write(f"Agent's Answer:\n {result} \n")
            f.write('---------------------------------------------------------------\n')
            f.write(f'==============================================================================================\n')
        continue
    # write the question and answer to the results file
    with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
        f.write(f'=============================Q{j}==============================================================\n')
        # with nice formating write the question that the agent will be asked
        f.write(f"Question: {question} \n")
        f.write('---------------------------------------------------------------\n')
        # with nice formating write the result that the agent gave
        f.write(f"Agent's Answer:\n {result} \n")
        f.write('---------------------------------------------------------------\n')
        # with nice formating write the answer that the agent will be asked
        f.write(f'==============================================================================================\n')
        
    j += 1

with open("C:\\Users\\cayde\\Desktop\\Grad_School_stuff\\data-534_expo_proj\\Synergistic_Computing_hf\\benchmarking\\deepmind_math_q_results.txt", "a", encoding='utf-8') as f:
    f.write(f"Number of Questions: {num_questions} \n")
    f.write(f"Number of Correct Answers: {num_correct} \n")
    f.write(f"Accuracy: {num_correct/num_questions} \n")

# print the number of questions and the number of correct answers
print(f"Number of Questions: {num_questions} \n")
print(f"Number of Correct Answers: {num_correct} \n")
print(f"Accuracy: {num_correct/num_questions} \n")
# Out:
# Number of Questions: 50
#
# Number of Correct Answers: 0
#
# Accuracy: 0.0
